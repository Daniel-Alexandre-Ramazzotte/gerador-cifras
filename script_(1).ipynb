# %%
import requests
from bs4 import BeautifulSoup
from reportlab.lib.pagesizes import A4
from reportlab.pdfgen import canvas
from reportlab.lib.utils import simpleSplit
from reportlab.lib.colors import Color
import re
import pandas as pd
import numpy as np
import time

# %%
notas_para_numeros = {
            'A': 0, 'A#': 1, 'Bb': 1, 'B': 2, 'C': 3, 'C#': 4, 'Db': 4, 'D': 5,
            'D#': 6, 'Eb': 6, 'E': 7, 'F': 8, 'F#': 9, 'Gb': 9, 'G': 10, 'G#': 11, 'Ab': 11
        }

def extrair_cifra(url, tom = 0):
    """
    Extrai a cifra de uma música a partir de uma URL do Cifra Club.

    :param url: URL da página da cifra.
    :param js: se será necessário javascript
    :return: String com a cifra extraída.
    """
    try:
        # Faz a requisição HTTP para abrir o link
        print(f"Acessando o link: {url}")
        site = requests.get(url, headers=headers)
        site.raise_for_status()  # Verifica se a requisição foi bem-sucedida

        # Parseia o conteúdo HTML
        soup = BeautifulSoup(site.content, 'html.parser')

        # Remove as tags <span> que contêm a classe 'tablatura'
        for tablatura in soup.find_all('span', class_='tablatura'):
            tablatura.decompose()

        # Encontra todas as tags <pre> que contêm a cifra
        pre_tags = soup.find_all('pre')

        # Extrai o texto, removendo linhas em branco extras
        cifras = []
        for pre in pre_tags:
            linhas = pre.get_text().splitlines()
            linhas_filtradas = [linha for linha in linhas if linha.strip()]
            cifras.append("\n".join(linhas_filtradas))



        return "\n".join(cifras)  # Junta todas as cifras em uma única string
    except Exception as e:
        print(f"Erro ao extrair a cifra: {e}")
        return None


# Gera um PDF com as cifras
def criar_pdf(cifras_com_titulos, output_file="cifra.pdf", fonte="Courier", tamanho_fonte=12):
    pdf = canvas.Canvas(output_file, pagesize=A4)
    largura_pagina, altura_pagina = A4
    margem_esquerda = 50
    margem_direita = largura_pagina / 2 + 20
    centro_x = largura_pagina / 2
    margem_superior = altura_pagina - 50
    margem_inferior = 50
    espacamento_linhas = tamanho_fonte + 2
    espacamento_titulos = 30

    primeira_pagina = True

    for titulo, cifra in cifras_com_titulos:
        if not primeira_pagina:
            pdf.showPage()
        primeira_pagina = False

        pdf.setFont("Helvetica-Bold", 16)
        pdf.drawCentredString(centro_x, margem_superior, titulo)

        pdf.setFont(fonte, tamanho_fonte)
        y_coluna_esquerda = margem_superior - espacamento_titulos
        y_coluna_direita = y_coluna_esquerda
        x_coluna_esquerda = margem_esquerda
        x_coluna_direita = margem_direita
        coluna_atual = 1

        for line in cifra.split("\n"):
            if coluna_atual == 1:
                if y_coluna_esquerda < margem_inferior:
                    coluna_atual = 2
                else:
                    pdf.drawString(x_coluna_esquerda, y_coluna_esquerda, line)
                    y_coluna_esquerda -= espacamento_linhas
            if coluna_atual == 2:
                if y_coluna_direita < margem_inferior:
                    break
                pdf.drawString(x_coluna_direita, y_coluna_direita, line)
                y_coluna_direita -= espacamento_linhas

    pdf.save()
    print(f"PDF salvo como {output_file}")

# Função para criar a coluna de links
def criar_coluna_links(df):
    try:
        def gerar_link(row):
            artista = row[1].lower().replace(" ", "-").replace("'", "").replace("ã", "a")\
                .replace("á", "a").replace("â", "a").replace("é", "e").replace("ê", "e")\
                .replace("í", "i").replace("ó", "o").replace("ô", "o").replace("ú", "u")\
                .replace("ç", "c")
            musica = row[0].lower().replace(" ", "-").replace("'", "").replace("ã", "a")\
                .replace("á", "a").replace("â", "a").replace("é", "e").replace("ê", "e")\
                .replace("í", "i").replace("ó", "o").replace("ô", "o").replace("ú", "u")\
                .replace("ç", "c")

            link = f"https://www.cifraclub.com.br/{artista}/{musica}/"

            if row['Simplificada'] != 0:
                link += "simplificada.html"

            if isinstance(row['Tom'], str) and any(c.isalpha() for c in row['Tom']):
                tom = row['Tom'].strip()
                if tom in notas_para_numeros:
                    numero_tom = notas_para_numeros[tom]
                    link += f"#key={numero_tom}"

            return link

        df['Link'] = df.apply(gerar_link, axis=1)
        print("Coluna de links criada com sucesso!")
        return df

    except Exception as e:
        print(f"Erro ao criar coluna de links: {e}")
        return None

# %%
path = 'repertorio.csv'
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36 Edg/134.0.0.0"}
repertorio = pd.read_csv(path)

# %%
repertorio = criar_coluna_links(repertorio)
# Out:
# Coluna de links criada com sucesso!
# C:\Users\IFPR - Astorga\AppData\Local\Temp\ipykernel_3508\3450411228.py:94: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   artista = row[1].lower().replace(" ", "-").replace("'", "").replace("ã", "a")\
# C:\Users\IFPR - Astorga\AppData\Local\Temp\ipykernel_3508\3450411228.py:98: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   musica = row[0].lower().replace(" ", "-").replace("'", "").replace("ã", "a")\

# %%
cifras_com_titulos = []

# Itera sobre as linhas do DataFrame
for index, row in repertorio.iterrows():
    link = row["Link"]
    titulo = row["Música"]
    print(f"Processando: {titulo} - {link}")


    cifra = transpose_chords(extrair_cifra(link),1)
    # Extrai a cifra do link
    #if repertorio['Tom'].isna()[index]:
    #    cifra = extrair_cifra(link, tom=1)
    #else:
    #    cifra = extrair_cifra(link)

    # Verifica se a cifra está vazia
    if cifra is None or not cifra.strip():  # Primeiro verifica se é None, depois se está vazia
        print(f"Processando: {titulo} - {link}")
        print(f"Aviso: A cifra para '{titulo}' está vazia ou não foi encontrada. Pulando esta música.")
    else:
        # Adiciona a tupla (título, cifra) à lista
        cifras_com_titulos.append((titulo, cifra))

criar_pdf(cifras_com_titulos, "cifras_la.pdf", 'Helvetica')
# Out:
# Processando: Mulher de Fases - https://www.cifraclub.com.br/raimundos/mulher-de-fases/#key=0
# Acessando o link: https://www.cifraclub.com.br/raimundos/mulher-de-fases/#key=0
# Processando: Anna Júlia - https://www.cifraclub.com.br/los-hermanos/anna-julia/
# Acessando o link: https://www.cifraclub.com.br/los-hermanos/anna-julia/
# Processando: Exagerado - https://www.cifraclub.com.br/cazuza/exagerado/
# Acessando o link: https://www.cifraclub.com.br/cazuza/exagerado/
# Processando: Enquanto Me Beija - https://www.cifraclub.com.br/jao/enquanto-me-beija/
# Acessando o link: https://www.cifraclub.com.br/jao/enquanto-me-beija/
# Processando: Meninos e Meninas - https://www.cifraclub.com.br/jao/meninos-e-meninas/
# Acessando o link: https://www.cifraclub.com.br/jao/meninos-e-meninas/
# Processando: Terra de Gigantes - https://www.cifraclub.com.br/engenheiros-do-hawaii/terra-de-gigantes/
# Acessando o link: https://www.cifraclub.com.br/engenheiros-do-hawaii/terra-de-gigantes/
# Processando: Era Um Garoto Que Como Eu Amava os Beatles e os Roling Stones - https://www.cifraclub.com.br/engenheiros-do-hawaii/era-um-garoto-que-como-eu-amava-os-beatles-e-os-roling-stones/
# Acessando o link: https://www.cifraclub.com.br/engenheiros-do-hawaii/era-um-garoto-que-como-eu-amava-os-beatles-e-os-roling-stones/
# Processando: O Tempo Não Para - https://www.cifraclub.com.br/cazuza/o-tempo-nao-para/
# Acessando o link: https://www.cifraclub.com.br/cazuza/o-tempo-nao-para/
# Processando: Pro Dia Nascer Feliz - https://www.cifraclub.com.br/cazuza/pro-dia-nascer-feliz/
# Acessando o link: https://www.cifraclub.com.br/cazuza/pro-dia-nascer-feliz/
# Processando: O Nosso Amor Gente Inventa - https://www.cifraclub.com.br/cazuza/o-nosso-amor-gente-inventa/
# Acessando o link: https://www.cifraclub.com.br/cazuza/o-nosso-amor-gente-inventa/
# Processando: Tempos Modernos - https://www.cifraclub.com.br/lulu-santos/tempos-modernos/
# Acessando o link: https://www.cifraclub.com.br/lulu-santos/tempos-modernos/
# Processando: Toda Forma de Amor - https://www.cifraclub.com.br/lulu-santos/toda-forma-de-amor/
# Acessando o link: https://www.cifraclub.com.br/lulu-santos/toda-forma-de-amor/
# Processando: Não Vá Embora - https://www.cifraclub.com.br/marisa-monte/nao-va-embora/
# Acessando o link: https://www.cifraclub.com.br/marisa-monte/nao-va-embora/
# Processando: Eu Sei Na Mira - https://www.cifraclub.com.br/marisa-monte/eu-sei-na-mira/
# Acessando o link: https://www.cifraclub.com.br/marisa-monte/eu-sei-na-mira/
# Processando: Um Certo Alguém - https://www.cifraclub.com.br/lulu-santos/um-certo-alguem/
# Acessando o link: https://www.cifraclub.com.br/lulu-santos/um-certo-alguem/
# Processando: Apenas Mais Uma de Amor - https://www.cifraclub.com.br/lulu-santos/apenas-mais-uma-de-amor/
# Acessando o link: https://www.cifraclub.com.br/lulu-santos/apenas-mais-uma-de-amor/
# Processando: Vilarejo - https://www.cifraclub.com.br/marisa-monte/vilarejo/
# Acessando o link: https://www.cifraclub.com.br/marisa-monte/vilarejo/
# Processando: O Que Me Importa - https://www.cifraclub.com.br/marisa-monte/o-que-me-importa/
# Acessando o link: https://www.cifraclub.com.br/marisa-monte/o-que-me-importa/
# Processando: Depois - https://www.cifraclub.com.br/marisa-monte/depois/
# Acessando o link: https://www.cifraclub.com.br/marisa-monte/depois/
# Processando: Ainda Bem - https://www.cifraclub.com.br/marisa-monte/ainda-bem/
# Acessando o link: https://www.cifraclub.com.br/marisa-monte/ainda-bem/
# Processando: Eu Te Devoro - https://www.cifraclub.com.br/djavan/eu-te-devoro/
# Acessando o link: https://www.cifraclub.com.br/djavan/eu-te-devoro/
# Processando: Oceano - https://www.cifraclub.com.br/djavan/oceano/
# Acessando o link: https://www.cifraclub.com.br/djavan/oceano/
# Processando: Epitáfio - https://www.cifraclub.com.br/titas/epitafio/
# Acessando o link: https://www.cifraclub.com.br/titas/epitafio/
# Processando: É Preciso Saber Viver - https://www.cifraclub.com.br/titas/e-preciso-saber-viver/
# Acessando o link: https://www.cifraclub.com.br/titas/e-preciso-saber-viver/
# Processando: Segundo Sol - https://www.cifraclub.com.br/cassia-eller/segundo-sol/
# Acessando o link: https://www.cifraclub.com.br/cassia-eller/segundo-sol/
# Processando: All Star - https://www.cifraclub.com.br/nando-reis/all-star/
# Acessando o link: https://www.cifraclub.com.br/nando-reis/all-star/
# Processando: De Janeiro Janeiro - https://www.cifraclub.com.br/nando-reis/de-janeiro-janeiro/
# Acessando o link: https://www.cifraclub.com.br/nando-reis/de-janeiro-janeiro/
# Processando: Pra Você Guardei Amor - https://www.cifraclub.com.br/nando-reis/pra-voce-guardei-amor/
# Acessando o link: https://www.cifraclub.com.br/nando-reis/pra-voce-guardei-amor/
# Processando: Sozinho - https://www.cifraclub.com.br/caetano-veloso/sozinho/
# Acessando o link: https://www.cifraclub.com.br/caetano-veloso/sozinho/
# Processando: Baby - https://www.cifraclub.com.br/gal-costa/baby/
# Acessando o link: https://www.cifraclub.com.br/gal-costa/baby/
# Processando: Na Sua Estante - https://www.cifraclub.com.br/pitty/na-sua-estante/
# Acessando o link: https://www.cifraclub.com.br/pitty/na-sua-estante/
# Processando: Malandragem - https://www.cifraclub.com.br/cassia-eller/malandragem/
# Acessando o link: https://www.cifraclub.com.br/cassia-eller/malandragem/
# Processando: Agora Só Falta Você - https://www.cifraclub.com.br/rita-lee/agora-so-falta-voce/
# Acessando o link: https://www.cifraclub.com.br/rita-lee/agora-so-falta-voce/
# Processando: Gostava Tanto de Você - https://www.cifraclub.com.br/tim-maia/gostava-tanto-de-voce/
# Acessando o link: https://www.cifraclub.com.br/tim-maia/gostava-tanto-de-voce/
# Processando: Baby 95 - https://www.cifraclub.com.br/liniker/baby-95/
# Acessando o link: https://www.cifraclub.com.br/liniker/baby-95/
# Processando: Não Quero Dinheiro - https://www.cifraclub.com.br/tim-maia/nao-quero-dinheiro/
# Acessando o link: https://www.cifraclub.com.br/tim-maia/nao-quero-dinheiro/
# Processando: O Descobridor dos Sete Mares - https://www.cifraclub.com.br/tim-maia/o-descobridor-dos-sete-mares/
# Acessando o link: https://www.cifraclub.com.br/tim-maia/o-descobridor-dos-sete-mares/
# Processando: Ela Partiu - https://www.cifraclub.com.br/tim-maia/ela-partiu/
# Acessando o link: https://www.cifraclub.com.br/tim-maia/ela-partiu/
# Processando: Aliança - https://www.cifraclub.com.br/tribalistas/alianca/
# Acessando o link: https://www.cifraclub.com.br/tribalistas/alianca/
# Processando: Velha Infância - https://www.cifraclub.com.br/tribalistas/velha-infancia/
# Acessando o link: https://www.cifraclub.com.br/tribalistas/velha-infancia/
# Processando: Como Eu Quero - https://www.cifraclub.com.br/kid-abelha/como-eu-quero/
# Acessando o link: https://www.cifraclub.com.br/kid-abelha/como-eu-quero/
# Processando: O Caderno - https://www.cifraclub.com.br/chico-buarque/o-caderno/
# Acessando o link: https://www.cifraclub.com.br/chico-buarque/o-caderno/
# Processando: Garotos ii O Outro Lado - https://www.cifraclub.com.br/leoni/garotos-ii-o-outro-lado/
# Acessando o link: https://www.cifraclub.com.br/leoni/garotos-ii-o-outro-lado/
# Processando: Oração - https://www.cifraclub.com.br/a-banda-mais-bonita-da-cidade/oracao/
# Acessando o link: https://www.cifraclub.com.br/a-banda-mais-bonita-da-cidade/oracao/
# PDF salvo como cifras_la.pdf

# %%
# 1. Abrir o arquivo CSV
df = pd.read_csv('repertorio.csv')

df.to_csv('repertorio.csv', index=False)

# %%
df = pd.read_csv('repertorio.csv')
df
# Out:
#                                                Música  \
# 0                                     Mulher de Fases
# 1                                          Anna Júlia
# 2                                           Exagerado
# 3                                   Enquanto Me Beija
# 4                                   Meninos e Meninas
# 5                                   Terra de Gigantes
# 6   Era Um Garoto Que Como Eu Amava os Beatles e o...
# 7                                    O Tempo Não Para
# 8                                Pro Dia Nascer Feliz
# 9                          O Nosso Amor Gente Inventa
# 10                                    Tempos Modernos
# 11                                 Toda Forma de Amor
# 12                                      Não Vá Embora
# 13                                     Eu Sei Na Mira
# 14                                    Um Certo Alguém
# 15                            Apenas Mais Uma de Amor
# 16                                           Vilarejo
# 17                                   O Que Me Importa
# 18                                             Depois
# 19                                          Ainda Bem
# 20                                       Eu Te Devoro
# 21                                             Oceano
# 22                                           Epitáfio
# 23                              É Preciso Saber Viver
# 24                                        Segundo Sol
# 25                                           All Star
# 26                                 De Janeiro Janeiro
# 27                              Pra Você Guardei Amor
# 28                                            Sozinho
# 29                                               Baby
# 30                                     Na Sua Estante
# 31                                        Malandragem
# 32                                Agora Só Falta Você
# 33                              Gostava Tanto de Você
# 34                                            Baby 95
# 35                                 Não Quero Dinheiro
# 36                       O Descobridor dos Sete Mares
# 37                                         Ela Partiu
# 38                                            Aliança
# 39                                     Velha Infância
# 40                                      Como Eu Quero
# 41                                          O Caderno
# 42                            Garotos ii O Outro Lado
# 43                                             Oração
#
#                           Artista      Gênero        Bloco  Tom  Simplificada
# 0                       Raimundos        Rock     Boy Like    A             0
# 1                    Los Hermanos        Rock     Boy Like  NaN             0
# 2                          Cazuza         MPB     Boy Like  NaN             0
# 3                             Jão         MPB     Boy Like  NaN             0
# 4                             Jão        Rock     Boy Like  NaN             0
# 5           Engenheiros do Hawaii        Rock     Boy Like  NaN             0
# 6           Engenheiros do Hawaii        Rock     Boy Like  NaN             0
# 7                          Cazuza         MPB     Boy Like  NaN             0
# 8                          Cazuza         MPB     Boy Like  NaN             0
# 9                          Cazuza       Breve     Boy Like  NaN             0
# 10                    Lulu Santos         MPB       Lovers  NaN             0
# 11                    Lulu Santos         MPB       Lovers  NaN             0
# 12                   Marisa Monte    Pop Rock       Lovers  NaN             0
# 13                   Marisa Monte         MPB       Lovers  NaN             0
# 14                    Lulu Santos         MPB       Lovers  NaN             0
# 15                    Lulu Santos    New Wave       Lovers  NaN             0
# 16                   Marisa Monte         MPB       Lovers  NaN             0
# 17                   Marisa Monte         MPB       Lovers  NaN             0
# 18                   Marisa Monte         MPB       Lovers  NaN             0
# 19                   Marisa Monte         MPB       Lovers  NaN             0
# 20                         Djavan         MPB  Brasil Core  NaN             0
# 21                         Djavan         MPB  Brasil Core  NaN             0
# 22                          Titãs        Rock  Brasil Core  NaN             0
# 23                          Titãs        Rock  Brasil Core  NaN             0
# 24                   Cássia Eller        Rock  Brasil Core  NaN             0
# 25                     Nando Reis        Rock  Brasil Core  NaN             0
# 26                     Nando Reis    Pop Rock  Brasil Core  NaN             0
# 27                     Nando Reis         MPB  Brasil Core  NaN             0
# 28                 Caetano Veloso         MPB  Brasil Core  NaN             0
# 29                      Gal Costa  Tropicália  Brasil Core  NaN             0
# 30                          Pitty        Rock     Rockstar  NaN             0
# 31                   Cássia Eller         MPB     Rockstar  NaN             0
# 32                       Rita Lee    Pop Rock     Rockstar  NaN             0
# 33                       Tim Maia        Soul     Rockstar  NaN             0
# 34                        Liniker         MPB     Rockstar  NaN             0
# 35                       Tim Maia        Soul     Rockstar  NaN             0
# 36                       Tim Maia    Pop Rock     Rockstar  NaN             0
# 37                       Tim Maia        Soul     Rockstar  NaN             0
# 38                    Tribalistas        Rock        Bonus  NaN             0
# 39                    Tribalistas         MPB        Bonus  NaN             0
# 40                     Kid Abelha    Pop Rock        Bonus  NaN             0
# 41                  Chico Buarque         MPB        Bonus  NaN             0
# 42                          Leoni        Rock        Bonus  NaN             0
# 43  A Banda Mais Bonita da Cidade         MPB        Bonus  NaN             0

# %%
cifra
# Out:
# '[Intro] D2  C9  D2  C9\nParte 3 de 5\n( Riff 2 )\n      D2    \nMeu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n( Riff 1 )\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n( Riff 2 )\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n( Riff 1 )\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n( Riff 2 )\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n( Riff 1 )\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n( Riff 2 )\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n( Riff 1 )\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\nCabe o meu amor\nCabem três vidas inteiras\nCabe uma penteadeira\nCabe nós dois\nCabe essa oração'

# %%
def transpose_chords(text, shift):
    notas_para_numeros = {
        'A': 0, 'A#': 1, 'Bb': 1, 'B': 2, 'C': 3, 'C#': 4, 'Db': 4, 'D': 5,
        'D#': 6, 'Eb': 6, 'E': 7, 'F': 8, 'F#': 9, 'Gb': 9, 'G': 10, 'G#': 11, 'Ab': 11
    }
    numeros_para_notas = {v: k for k, v in notas_para_numeros.items()}

    def transpose_match(match):
        original_chord = match.group(0)
        root_note = match.group(1)

        if root_note in notas_para_numeros:
            new_note_number = (notas_para_numeros[root_note] + shift) % 12
            new_note = numeros_para_notas[new_note_number]
            return new_note + original_chord[len(root_note):]

        return original_chord  # Retorna sem alterações se não for um acorde válido

    # Ajuste na regex para garantir que acordes complexos sejam detectados corretamente
    chord_pattern = re.compile(r'(?<=\n|\s|\[)([A-G](#|b)?)(m|M|maj|min|dim|aug|sus|add|[0-9]*)\b')
    transposed_text = chord_pattern.sub(transpose_match, text)

    return transposed_text

# %%
cifra
# Out:
# '[Intro] D2  C9  D2  C9\nParte 3 de 5\n( Riff 2 )\n      D2    \nMeu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n( Riff 1 )\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n( Riff 2 )\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n( Riff 1 )\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n( Riff 2 )\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n( Riff 1 )\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n( Riff 2 )\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n( Riff 1 )\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\n        D2\nCabe o meu amor\n        C9\nCabem três vidas inteiras\n       D2\nCabe uma penteadeira\n   C9\nCabe nós dois\n            D2\nCabe até o meu amor\n         A          Bm7\nEssa é a última oração\n        G\nPra salvar seu coração\nCoração não é tão simples quanto pensa\nNele cabe o que não cabe na dispensa\nCabe o meu amor\nCabem três vidas inteiras\nCabe uma penteadeira\nCabe nós dois\nCabe essa oração'

# %%
linhas_filtradas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 linhas_filtradas
#
# NameError: name 'linhas_filtradas' is not defined
